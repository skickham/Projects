# %% [markdown]
# # JC Penny Store Closings
#
#
# ## Workflow
#
# Investigate JC Penny store closings$^1$  by:
#
# * Tagging locations as Urban vs Rural (using population density from the Data Observatory)
# * Draw 10 minutes walk or drive isochrones based on whether the location is urban or not
# * Visualize data with cartoframes
# * Augment isochrones with Data Observatory measures
# * Visualize data in Builder and add widgets for specific measures and store properties
#
# Final dashboard: https://team.carto.com/u/eschbacher/builder/0592fcae-3026-11e7-b861-0e3ebc282e83/embed
#
# 1. closing status is real, but the actual close date is chosen randomly from the last five years

# %% [markdown]
# ## Installing dependencies
#
# Install [cartoframes](https://github.com/cartodb/cartoframes) (which is currently in beta). I recommend installing in a virtual environment to keep things clean and sandboxed.
#
# ## Getting the data
#
# Download the JC Penny store location data from here:
# * <http://eschbacher.carto.com/api/v2/sql?q=select%20*%20from%20jc_penny_stores&format=csv&filename=jc_penny_stores>

# %% [markdown]
# ## Workflow for obtaining data
#
# Pull JC Penny locations from my CARTO account into cartoframes

# %%
import pandas as pd
import cartoframes
import json
import warnings
warnings.filterwarnings('ignore')

USERNAME = 'skickham' # <-- Put your carto username here
APIKEY = '79c4ab7de1e6c6794a3b84b00ff0bf45659ce668' # <-- Put your carto api key here

# use cartoframes.credentials.set_creds() to save credentials for future use
cc = cartoframes.CartoContext(api_key=APIKEY,
                              base_url='https://{}.carto.com/'.format(USERNAME))
table_name = 'jc_penny_stores'

# load JC Penny locations into DataFrame
df = cc.read(table_name)
df.head()
# Out:
#                status  distance  allhomes_zhvi_predenom_2016_08  \
# cartodb_id
# 405         retaining   24140.0                             NaN
# 3             closing   24140.0                             NaN
# 4             closing   24140.0                        155500.0
# 5           retaining   24140.0                             NaN
# 6           retaining   24140.0                             NaN
#
#                                          the_geom_webmercator  \
# cartodb_id
# 405         0101000020110F0000D4179582CCE761C14E29ED592A54...
# 3           0101000020110F00006F876C7D722462C10CFF22F21C57...
# 4           0101000020110F00003AD009EF347862C110A1BA13DE0E...
# 5           0101000020110F0000E4EBC3C39B6E62C139F61E854967...
# 6           0101000020110F0000D2E0C270202362C171737DD2BBF7...
#
#                                                    name state_abb  \
# cartodb_id
# 405                          JCPenney - Richmond Centre        KY
# 3              JCPenney - Colonial University in Auburn        AL
# 4           JCPenney - Clnl Prom @tannehill in Bessemer        AL
# 5                         JCPenney - Cullman Shopg Cntr        AL
# 6                JCPenney - Wiregrass Commons in Dothan        AL
#
#             total_pop_area_2011_2015 closed_date           phone     state  \
# cartodb_id
# 405                       368.266243         NaT  (859) 626-7857  Kentucky
# 3                         866.007594  2014-04-17  (334) 826-1954   Alabama
# 4                         174.355475  2015-07-21  (205) 565-2720   Alabama
# 5                           6.903157         NaT  (256) 739-3726   Alabama
# 6                         494.424072         NaT  (334) 794-0531   Alabama
#
#                            address  \
# cartodb_id
# 405          2037 Lantern Ridge Dr
# 3           1627 Opelika Rd Ste 69
# 4              4835 Promenade Pkwy
# 5                711 Second Ave NW
# 6           900 Commons Dr Ste 900
#
#                                                      the_geom
# cartodb_id
# 405         0101000020E6100000E1EF17B3251555C04CE2AC889ADE...
# 3           0101000020E61000000AD6389B8E5C55C07619FED30D50...
# 4           0101000020E6100000E96514CB2DBF55C07F2F8507CDAA...
# 5           0101000020E61000003468E89FE0B355C01475E61E1258...
# 6           0101000020E6100000BEF6CC92005B55C0AF44A0FA0741...

# %% [markdown]
# ## JC Penny Store Closings
#
# * Purple = stores closing
# * Orange = stores staying open

# %%
from cartoframes import Layer   # can map my layer inside python notebook 
from cartoframes.styling import vivid

cc.map(layers=Layer(table_name,
                    color={'column': 'status', 'scheme': vivid(10, 'category')}),
       interactive=False)
# Out:
# <img src="https://skickham.carto.com/api/v1/map/static/named/cartoframes_ver20170406_layers1_time0_baseid1_labels0_zoom0/800/400.png?config=%7B%22cartocss_0%22%3A+%22%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D3%5D+%7B++polygon-opacity%3A+0.9%3B+line-color%3A+%23FFF%3B+polygon-fill%3A+ramp%28%5Bstatus%5D%2C+cartocolor%28Vivid%29%2C+category%2810%29%29%3B+line-comp-op%3A+hard-light%3B+polygon-gamma%3A+0.5%3B+line-opacity%3A+0.25%3B+line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D1%5D+%7B++marker-fill%3A+ramp%28%5Bstatus%5D%2C+cartocolor%28Vivid%29%2C+category%2810%29%29%3B+marker-allow-overlap%3A+true%3B+marker-fill-opacity%3A+1%3B+marker-line-color%3A+%23000%3B+marker-width%3A+10%3B+marker-line-opacity%3A+1%3B+marker-line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D2%5D+%7B++line-color%3A+ramp%28%5Bstatus%5D%2C+cartocolor%28Vivid%29%2C+category%2810%29%29%3B+line-width%3A+1.5%3B%7D+%22%2C+%22basemap_url%22%3A+%22https%3A%2F%2Fcartodb-basemaps-%7Bs%7D.global.ssl.fastly.net%2Fdark_all%2F%7Bz%7D%2F%7Bx%7D%2F%7By%7D.png%22%2C+%22sql_0%22%3A+%22SELECT+%2A+FROM+jc_penny_stores%22%7D&anti_cache=0.971135235891" />

# %% [markdown]
# ## Augment with DO to get 'urban-ness' metric (population density)

# %%
# get population, other measures within 5 minute walk time
# More info about this Data Observatory measure here:
#  https://cartodb.github.io/bigmetadata/united_states/age_gender.html#total-population
df = cc.data_augment(table_name, [{'numer_id': 'us.census.acs.B01003001',
                                   'normalization': 'area',
                                   'numer_timespan': '2011 - 2015'}])
df.head()
# Out:
#                status  distance  allhomes_zhvi_predenom_2016_08  \
# cartodb_id
# 394         retaining   24140.0                             NaN
# 570         retaining   24140.0                             NaN
# 591         retaining   24140.0                             NaN
# 2           retaining   24140.0                             NaN
# 1           retaining   24140.0                        153300.0
#
#                                          the_geom_webmercator  \
# cartodb_id
# 394         0101000020110F0000720A5E60110862C1270A265C5B4E...
# 570         0101000020110F0000354B5FE848B163C192BE1767EEA8...
# 591         0101000020110F000040C4A6BC489368C188BC286C4709...
# 2           0101000020110F0000C49A63207B5D62C118FDB9263807...
# 1           0101000020110F000096B58E53286E62C12515EDDFD8F1...
#
#                                                   name state_abb  \
# cartodb_id
# 394             JCPenney - Bradford Sq in Hopkinsville        KY
# 570                              JCPenney - Washington        MO
# 591                     JCPenney - Elko Shopping Plaza        NV
# 2               JCPenney - Covington Mall in Andalusia        AL
# 1           JCPenney - Colonial Promenade in Alabaster        AL
#
#             total_pop_area_2011_2015 closed_date           phone     state  \
# cartodb_id
# 394                        28.082250         NaT  (270) 886-9441  Kentucky
# 570                        14.059081         NaT  (636) 390-2405  Missouri
# 591                       131.475164         NaT  (775) 738-7274    Nevada
# 2                         152.558767         NaT  (334) 222-8484   Alabama
# 1                          62.527422         NaT  (205) 663-2763   Alabama
#
#                           address  \
# cartodb_id
# 394         4000 Ft Campbell Blvd
# 570              5886 Highway 100
# 591                 2190 Idaho St
# 2              922 River Falls St
# 1               340 S Colonial Dr
#
#                                                      the_geom
# cartodb_id
# 394         0101000020E61000006AD95A5F243B55C08104C58F31D9...
# 570         0101000020E61000001FD95C35CF2F57C039F06AB9332D...
# 591         0101000020E610000069C70DBF9BEF5CC00342EBE1CB6C...
# 2           0101000020E61000006D7022FAB59F55C0A4213E0B9D50...
# 1           0101000020E6100000323CF6B358B355C02D5BEB8B849C...

# %% [markdown]
# ## Get a sense of the range of data

# %%
df.describe()
# Out:
#        distance  allhomes_zhvi_predenom_2016_08  total_pop_area_2011_2015
# count    1078.0                    7.070000e+02               1078.000000
# mean    24140.0                    2.235372e+05                696.898505
# std         0.0                    1.588468e+05               1724.807367
# min     24140.0                    4.380000e+04                  0.000000
# 25%     24140.0                    1.302000e+05                 57.923748
# 50%     24140.0                    1.830000e+05                347.338072
# 75%     24140.0                    2.480500e+05                814.271287
# max     24140.0                    1.765800e+06              22221.862461

# %% [markdown]
# ## Create isochrones based on travel inferences
#
# Create a derivative table with geometries as isochrones of walk/drive times from store locations. If pop density is above 5000 people / sq. km., assume it's a walkable area. Otherwise, assume cars are the primary mode of transit.
#
# **Note:** This functionality is a planned cartoframes method.

# %%
# %%time
df = cc.query('''
    SELECT 
        CASE WHEN total_pop_area_2011_2015 > 5000
             THEN ST_Buffer(the_geom::geography, 800)::geometry
             ELSE ST_Buffer(the_geom::geography, 1200)::geometry
             END as the_geom,
        {keep_columns}
    FROM
        {table_name}
             '''.format(table_name=table_name,
                        keep_columns=', '.join(set(df.columns) - {'the_geom', 'the_geom_webmercator'})),
             table_name=(table_name + '_isochrones'))
# Out:
# ---------------------------------------------------------------------------
# CartoException                            Traceback (most recent call last)
# <ipython-input-21-02add2fa979b> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"df = cc.query('''\n    SELECT \n        CASE WHEN total_pop_area_2011_2015 > 5000\n             THEN ST_Buffer(the_geom::geography, 800)::geometry\n             ELSE ST_Buffer(the_geom::geography, 1200)::geometry\n             END as the_geom,\n        {keep_columns}\n    FROM\n        {table_name}\n             '''.format(table_name=table_name,\n                        keep_columns=', '.join(set(df.columns) - {'the_geom', 'the_geom_webmercator'})),\n             table_name=(table_name + '_isochrones'))")
#
# C:\Users\skick\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# C:\Users\skick\Anaconda2\lib\site-packages\IPython\core\magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\skick\Anaconda2\lib\site-packages\IPython\core\magics\execution.pyc in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# c:\users\skick\cartoframes\cartoframes\context.pyc in query(self, query, table_name)
#     286             self._debug_print(create_table_query=create_table_query)
#     287
# --> 288             create_table_res = self.sql_client.send(create_table_query)
#     289             self._debug_print(create_table_res=create_table_res)
#     290
#
# c:\users\skick\cartoframes\src\carto\carto\sql.pyc in send(self, sql, parse_json, do_post, format)
#      80             return self.auth_client.get_response_data(resp, parse_json)
#      81         except Exception as e:
# ---> 82             raise CartoException(e)
#      83
#      84
#
# CartoException: [u'column "median_income_2011_2015" does not exist']

# %% [markdown]
# If this fails because of a lack of credits (i.e., reaching quota), then replace the `(cdb_isochrone(the_geom, 'walk', Array[600])).the_geom` pieces with `ST_Buffer(the_geom::geography, 800)::geometry` for an approximate 10 minute walk ('crow flies' distance), and `ST_Buffer(the_geom::geography, 12000)::geometry` for an approximate 10 minute drive (assuming 45 mph on average for 10 minutes).

# %%
iso_table_name = (table_name + '_isochrones')

# %%
ccwrite()

# %%
df.head()
# Out:
#                status  distance  allhomes_zhvi_predenom_2016_08  \
# cartodb_id
# 1           retaining   24140.0                             NaN
# 2           retaining   24140.0                             NaN
# 3           retaining   24140.0                             NaN
# 4           retaining   24140.0                             NaN
# 5           retaining   24140.0                        153300.0
#
#                                          the_geom_webmercator  \
# cartodb_id
# 1           0103000020110F000001000000210000007EC70FA3AC00...
# 2           0103000020110F00000100000021000000DF55ECDED1A9...
# 3           0103000020110F00000100000021000000B4F9B1548C8B...
# 4           0103000020110F0000010000002100000091577154A056...
# 5           0103000020110F000001000000210000006288F4582867...
#
#                                                   name state_abb  \
# cartodb_id
# 1               JCPenney - Bradford Sq in Hopkinsville        KY
# 2                                JCPenney - Washington        MO
# 3                       JCPenney - Elko Shopping Plaza        NV
# 4               JCPenney - Covington Mall in Andalusia        AL
# 5           JCPenney - Colonial Promenade in Alabaster        AL
#
#             total_pop_area_2011_2015 closed_date           phone     state  \
# cartodb_id
# 1                          28.082250         NaT  (270) 886-9441  Kentucky
# 2                          14.059081         NaT  (636) 390-2405  Missouri
# 3                         131.475164         NaT  (775) 738-7274    Nevada
# 4                         152.558767         NaT  (334) 222-8484   Alabama
# 5                          62.527422         NaT  (205) 663-2763   Alabama
#
#                           address  \
# cartodb_id
# 1           4000 Ft Campbell Blvd
# 2                5886 Highway 100
# 3                   2190 Idaho St
# 4              922 River Falls St
# 5               340 S Colonial Dr
#
#                                                      the_geom
# cartodb_id
# 1           0103000020E61000000100000021000000C1E021C96F32...
# 2           0103000020E6100000010000002100000031E2D7130527...
# 3           0103000020E61000000100000021000000E40DF6EF7FE6...
# 4           0103000020E61000000100000021000000EF6044CFA397...
# 5           0103000020E61000000100000021000000103573C11AAB...

# %%
from cartoframes import BaseMap
cc.map(layers=[BaseMap('light'),
               Layer(table_name + '_isochrones'),
               Layer(table_name)],
       zoom=12, lng=-73.9668, lat=40.7306,
       interactive=False) # or True
# Out:
# <img src="https://skickham.carto.com/api/v1/map/static/named/cartoframes_ver20170406_layers2_time0_baseid0_labels0_zoom1/800/400.png?lat=40.7306&lon=-73.9668&config=%7B%22cartocss_1%22%3A+%22%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D3%5D+%7B++polygon-opacity%3A+0.9%3B+line-color%3A+%23FFF%3B+polygon-fill%3A+%234A5798%3B+line-comp-op%3A+hard-light%3B+polygon-gamma%3A+0.5%3B+line-opacity%3A+0.25%3B+line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D1%5D+%7B++marker-fill%3A+%234A5798%3B+marker-allow-overlap%3A+true%3B+marker-fill-opacity%3A+1%3B+marker-line-color%3A+%23FFF%3B+marker-width%3A+10%3B+marker-line-opacity%3A+1%3B+marker-line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D2%5D+%7B++line-color%3A+%234A5798%3B+line-width%3A+1.5%3B%7D+%22%2C+%22cartocss_0%22%3A+%22%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D3%5D+%7B++polygon-opacity%3A+0.9%3B+line-color%3A+%23FFF%3B+polygon-fill%3A+%234ABD9A%3B+line-comp-op%3A+hard-light%3B+polygon-gamma%3A+0.5%3B+line-opacity%3A+0.25%3B+line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D1%5D+%7B++marker-fill%3A+%234ABD9A%3B+marker-allow-overlap%3A+true%3B+marker-fill-opacity%3A+1%3B+marker-line-color%3A+%23FFF%3B+marker-width%3A+10%3B+marker-line-opacity%3A+1%3B+marker-line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D2%5D+%7B++line-color%3A+%234ABD9A%3B+line-width%3A+1.5%3B%7D+%22%2C+%22basemap_url%22%3A+%22https%3A%2F%2Fcartodb-basemaps-%7Bs%7D.global.ssl.fastly.net%2Flight_all%2F%7Bz%7D%2F%7Bx%7D%2F%7By%7D.png%22%2C+%22sql_0%22%3A+%22SELECT+%2A+FROM+jc_penny_stores_isochrones%22%2C+%22sql_1%22%3A+%22SELECT+%2A+FROM+jc_penny_stores%22%7D&anti_cache=0.485080834664&zoom=12" />

# %%
# show choropleth of isochrones by pop density
from cartoframes.styling import vivid
cc.map(layers=[Layer(table_name + '_isochrones',
                    color='total_pop_area_2011_2015'),
              Layer(table_name, size=6, color={'column': 'status', 'scheme': vivid(2)})],
       zoom=8, lng=-74.7729, lat=39.9771,
       interactive=False)  #or can do True
# Out:
# <img src="https://skickham.carto.com/api/v1/map/static/named/cartoframes_ver20170406_layers2_time0_baseid1_labels0_zoom1/800/400.png?lat=39.9771&lon=-74.7729&config=%7B%22cartocss_1%22%3A+%22%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D3%5D+%7B++polygon-opacity%3A+0.9%3B+line-color%3A+%23FFF%3B+polygon-fill%3A+ramp%28%5Bstatus%5D%2C+cartocolor%28Vivid%29%2C+category%282%29%29%3B+line-comp-op%3A+hard-light%3B+polygon-gamma%3A+0.5%3B+line-opacity%3A+0.25%3B+line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D1%5D+%7B++marker-fill%3A+ramp%28%5Bstatus%5D%2C+cartocolor%28Vivid%29%2C+category%282%29%29%3B+marker-allow-overlap%3A+true%3B+marker-fill-opacity%3A+1%3B+marker-line-color%3A+%23000%3B+marker-width%3A+6%3B+marker-line-opacity%3A+1%3B+marker-line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D2%5D+%7B++line-color%3A+ramp%28%5Bstatus%5D%2C+cartocolor%28Vivid%29%2C+category%282%29%29%3B+line-width%3A+1.5%3B%7D+%22%2C+%22cartocss_0%22%3A+%22%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D3%5D+%7B++polygon-opacity%3A+0.9%3B+line-color%3A+%23FFF%3B+polygon-fill%3A+ramp%28%5Btotal_pop_area_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%285%29%29%3B+line-comp-op%3A+hard-light%3B+polygon-gamma%3A+0.5%3B+line-opacity%3A+0.25%3B+line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D1%5D+%7B++marker-fill%3A+ramp%28%5Btotal_pop_area_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%285%29%29%3B+marker-allow-overlap%3A+true%3B+marker-fill-opacity%3A+1%3B+marker-line-color%3A+%23000%3B+marker-width%3A+10%3B+marker-line-opacity%3A+1%3B+marker-line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D2%5D+%7B++line-color%3A+ramp%28%5Btotal_pop_area_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%285%29%29%3B+line-width%3A+1.5%3B%7D+%22%2C+%22basemap_url%22%3A+%22https%3A%2F%2Fcartodb-basemaps-%7Bs%7D.global.ssl.fastly.net%2Fdark_all%2F%7Bz%7D%2F%7Bx%7D%2F%7By%7D.png%22%2C+%22sql_0%22%3A+%22SELECT+%2A+FROM+jc_penny_stores_isochrones%22%2C+%22sql_1%22%3A+%22SELECT+%2A+FROM+jc_penny_stores%22%7D&anti_cache=0.209811965988&zoom=8" />

# %%
# Data Observatory measures: median income, male age 30-34 (both ACS)
# Male age 30-34: https://cartodb.github.io/bigmetadata/united_states/age_gender.html#male-age-30-to-34
# Median Income: https://cartodb.github.io/bigmetadata/united_states/income.html#median-household-income-in-the-past-12-months

# Note: this may take a minute or two because all the measures are being calculated based on the custom geographies
#       that are passed in using spatially interpolated calculations (area-weighted measures)

data_obs_measures = [{'numer_id': 'us.census.acs.B01001012'},
                     {'numer_id': 'us.census.acs.B19013001'}]
df = cc.data_augment(table_name + '_isochrones', data_obs_measures)
df.head()
# Out:
#                status  distance  allhomes_zhvi_predenom_2016_08  \
# cartodb_id
# 1           retaining   24140.0                             NaN
# 2           retaining   24140.0                             NaN
# 3           retaining   24140.0                             NaN
# 4           retaining   24140.0                             NaN
# 5           retaining   24140.0                        153300.0
#
#                                          the_geom_webmercator  \
# cartodb_id
# 1           0103000020110F000001000000210000007EC70FA3AC00...
# 2           0103000020110F00000100000021000000DF55ECDED1A9...
# 3           0103000020110F00000100000021000000B4F9B1548C8B...
# 4           0103000020110F0000010000002100000091577154A056...
# 5           0103000020110F000001000000210000006288F4582867...
#
#                                                   name state_abb  \
# cartodb_id
# 1               JCPenney - Bradford Sq in Hopkinsville        KY
# 2                                JCPenney - Washington        MO
# 3                       JCPenney - Elko Shopping Plaza        NV
# 4               JCPenney - Covington Mall in Andalusia        AL
# 5           JCPenney - Colonial Promenade in Alabaster        AL
#
#             male_30_to_34_2011_2015  total_pop_area_2011_2015 closed_date  \
# cartodb_id
# 1                          0.032911                 28.082250         NaT
# 2                          0.034218                 14.059081         NaT
# 3                          0.043822                131.475164         NaT
# 4                          0.027246                152.558767         NaT
# 5                          0.036400                 62.527422         NaT
#
#                      phone     state                address  \
# cartodb_id
# 1           (270) 886-9441  Kentucky  4000 Ft Campbell Blvd
# 2           (636) 390-2405  Missouri       5886 Highway 100
# 3           (775) 738-7274    Nevada          2190 Idaho St
# 4           (334) 222-8484   Alabama     922 River Falls St
# 5           (205) 663-2763   Alabama      340 S Colonial Dr
#
#             median_income_2011_2015  \
# cartodb_id
# 1                      41263.301112
# 2                      41750.934264
# 3                      74506.782991
# 4                      36108.890613
# 5                      69592.437593
#
#                                                      the_geom
# cartodb_id
# 1           0103000020E61000000100000021000000C1E021C96F32...
# 2           0103000020E6100000010000002100000031E2D7130527...
# 3           0103000020E61000000100000021000000E40DF6EF7FE6...
# 4           0103000020E61000000100000021000000EF6044CFA397...
# 5           0103000020E61000000100000021000000103573C11AAB...

# %% [markdown]
# ## Visualize isochrones based on Data Observatory measure

# %%
cc.map(layers=Layer(table_name + '_isochrones',
                    color='median_income_2011_2015'),
       zoom=8, lng=-74.3115, lat=40.1621,
       interactive=False)
# Out:
# <img src="https://skickham.carto.com/api/v1/map/static/named/cartoframes_ver20170406_layers1_time0_baseid1_labels0_zoom1/800/400.png?lat=40.1621&lon=-74.3115&config=%7B%22cartocss_0%22%3A+%22%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D3%5D+%7B++polygon-opacity%3A+0.9%3B+line-color%3A+%23FFF%3B+polygon-fill%3A+ramp%28%5Bmedian_income_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%285%29%29%3B+line-comp-op%3A+hard-light%3B+polygon-gamma%3A+0.5%3B+line-opacity%3A+0.25%3B+line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D1%5D+%7B++marker-fill%3A+ramp%28%5Bmedian_income_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%285%29%29%3B+marker-allow-overlap%3A+true%3B+marker-fill-opacity%3A+1%3B+marker-line-color%3A+%23000%3B+marker-width%3A+10%3B+marker-line-opacity%3A+1%3B+marker-line-width%3A+0.5%3B%7D+%23layer%5B%27mapnik%3A%3Ageometry_type%27%3D2%5D+%7B++line-color%3A+ramp%28%5Bmedian_income_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%285%29%29%3B+line-width%3A+1.5%3B%7D+%22%2C+%22basemap_url%22%3A+%22https%3A%2F%2Fcartodb-basemaps-%7Bs%7D.global.ssl.fastly.net%2Fdark_all%2F%7Bz%7D%2F%7Bx%7D%2F%7By%7D.png%22%2C+%22sql_0%22%3A+%22SELECT+%2A+FROM+jc_penny_stores_isochrones%22%7D&anti_cache=0.574294982688&zoom=8" />

# %% [markdown]
# ## Builder Dashboard
#
# https://team.carto.com/u/eschbacher/builder/0592fcae-3026-11e7-b861-0e3ebc282e83/embed

# %%
from IPython.display import HTML
HTML('<iframe width="100%" height="520" frameborder="0" src="https://team.carto.com/u/eschbacher/builder/0592fcae-3026-11e7-b861-0e3ebc282e83/embed" allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>')
# Out:
# <iframe width="100%" height="520" frameborder="0" src="https://team.carto.com/u/eschbacher/builder/0592fcae-3026-11e7-b861-0e3ebc282e83/embed" allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>
